# %% [markdown]
# # Fundamentals
# - **Basic Types**
#    - integer (number without decimals)
#    - float (number with decimals)
#    - string (text)
#    - boolean (true/false)
# - **Aggregate Types**
#     - lists (sequence of items)
#     - tuples (immutable lists)
#     - dictionaries (key-value pairs)
# - **Flow Control**
#     - if.. elif.. else.. (Conditionals)
#     - for i in seq  (For Loop)
#     - while i > 0  (While Loop)
# - **Functions**
#     - def myfunc(a, b, c=0)
# - **Classes**
#     - class MyClass

# %% [markdown]
# ## **Basic types**

# %%
a = 7  # integer
b = 3.14  # float
c = "ciao"  # string
d = "ciao"  # also string
e = False  # boolean

# %% [markdown]
# ## **Lists**
# editable (mutable) sequence of items

# %%
my_wierd_list = ["Jim", 3, False, [1, 2]]  # each element can be a different type

my_list = ["John", "Paul", "George", "Ringo"]  # most common is all the same type

# %%
my_list
# Out:
# ['John', 'Paul', 'George', 'Ringo']

# %%
# get first item
my_list[3]
# Out:
# 'Ringo'

# %%
# get last item
my_list[-2]
# Out:
# 'George'

# %%
# get second item?
my_list[1]
# Out:
# 'Paul'

# %%
# get second-to-last item?
...

# %% [markdown]
# ### *List slicing*
# also used for **arrays**, **matrices**, **pd.Series** and **strings**
#
# ***LIST[start:end:step]***

# %%
# taking first two
my_list[:2]  # same as my_list[0:2:1]
# Out:
# ['John', 'Paul']

# %%
# taking last two
my_list[-2:]  # same as my_list[-2::1]
# Out:
# ['George', 'Ringo']

# %%
# taking middle two?
my_list[1:3]
# Out:
# ['Paul', 'George']

# %%
starting_idx = int(len(my_list) / 2 - 1)
ending_idx = int(len(my_list) / 2 + 1)

my_list[starting_idx:ending_idx]
# Out:
# ['Paul', 'George']

# %%
# taking one every two (even numbers)
my_list[::2]
# Out:
# ['John', 'George']

# %%
# reversing the order?
my_list[::-1]  # not amending the list
# my_list.reverse() # inplace
# Out:
# ['Ringo', 'THE George', 'Paul', 'John']

# %%
# sorting a list
sorted(my_list)
# Out:
# ['George', 'John', 'Paul', 'Ringo']

# %%
my_list[2]
# Out:
# 'George'

# %%
# changing one value
print("before: ", my_list)
my_list[2] = "THE George"
print("after: ", my_list)
# Out:
# before:  ['John', 'Paul', 'George', 'Ringo']
# after:  ['John', 'Paul', 'THE George', 'Ringo']

# %%
# adding elements to a list
my_list.append("Pete")

my_list
# Out:
# ['Ringo', 'THE George', 'Paul', 'John', 'Pete']

# %%
# checking if element in list
"Pete" in my_list
# Out:
# True

# %%
len([1, 2, 3]), len({"a": 5, "b": 2})
# Out:
# (3, 2)

# %% [markdown]
# ## **Tuples** (very briefly)
# basically lists that cannot be edited (immutable)

# %%
my_tuple = ("John", "Paul", "George", "Ringo")  # most common is all the same type

sorted(my_tuple[-2:])
# Out:
# ['George', 'Ringo']

# %%
my_tuple.append(42)  # won't work
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-1633a8bf04b2> in <module>()
# ----> 1 my_tuple.append(42)  # won't work
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
my_tuple[2] = "THE George"  # won't work
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-cf84bf8e4fd8> in <module>()
# ----> 1 my_tuple[2] = 'THE George'  # won't work
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## **Dictionaries**
# Collection of key-value pairs

# %%
the_beatles_instruments = {
    "John": ["vocals", "rhythm and lead guitar", "keyboards", "harmonica", "bass guitar"],
    "Paul": ["vocals", "bass guitar", "rhythm and lead guitar", "keyboards", "drums"],
    "George": ["lead and rhythm guitar", "vocals", "sitar", "keyboards", "bass guitar"],
    "Ringo": ["drums", "percussion", "vocals"],
}

the_beatles_tenure = {
    "John": {"start": 1960, "end": 1969},
    "Paul": [1960, 1970],
    "George": (1960, 1970),
    "Ringo": "1962–1970",
}

# %%
the_beatles_instruments.__getitem__("Paul")
# Out:
# ['vocals', 'bass guitar', 'rhythm and lead guitar', 'keyboards', 'drums']

# %%
# accessing a value
the_beatles_instruments["Paul"]
# Out:
# ['vocals', 'bass guitar', 'rhythm and lead guitar', 'keyboards', 'drums']

# %%
the_beatles_tenure["Paul"][0]
# Out:
# 1960

# %%
# starting year of John?
the_beatles_tenure["John"]["start"]
# Out:
# 1960

# %%
the_beatles_instruments["Pete"] = 5

# %%
# adding a new value
the_beatles_instruments["Pete"] = ["drums"]

the_beatles_instruments
# Out:
# {'George': ['lead and rhythm guitar',
#   'vocals',
#   'sitar',
#   'keyboards',
#   'bass guitar'],
#  'John': ['vocals',
#   'rhythm and lead guitar',
#   'keyboards',
#   'harmonica',
#   'bass guitar'],
#  'Paul': ['vocals',
#   'bass guitar',
#   'rhythm and lead guitar',
#   'keyboards',
#   'drums'],
#  'Pete': ['drums'],
#  'Ringo': ['drums', 'percussion', 'vocals']}

# %%
# getting all keys
for i in the_beatles_tenure.keys():
    print(i)
# Out:
# John
# Paul
# George
# Ringo

# %%
# getting all values
the_beatles_tenure.values()
# Out:
# dict_values([{'start': 1960, 'end': 1969}, [1960, 1970], (1960, 1970), '1962–1970'])

# %%
# getting all keys-values as pairs
for i in the_beatles_tenure.items():
    print(i)
# Out:
# ('John', {'start': 1960, 'end': 1969})
# ('Paul', [1960, 1970])
# ('George', (1960, 1970))
# ('Ringo', '1962–1970')

# %% [markdown]
# ## **If Statement**
# diverting the execution flow depending on 1+ condition

# %%
happy = False
know_it = True

# %%
if happy == True and know_it is True:
    print("hands go clap clap")
elif know_it is False:
    print("hands go clap")
else:
    print("...silence...")
# Out:
# ...silence...

# %%
# what result do I expect with.. ?
happy = True
know_it = False

# %%
# what result do I expect with.. ?
happy = False
know_it = True

# %%
# what result do I expect with.. ?
happy = False
know_it = False

# %% [markdown]
# ## **For Loop**
# runs a part of the code multiple times: one for every item in the sequence

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
d = {1: "a", 4: "b"}

for i in d.items():
    k = i[0]
    v = i[1]
    print("key:", k, "value:", v)


for k, v in d.items():
    print("key:", k, "value:", v)
# Out:
# key: 1 value: a
# key: 4 value: b

# %%
for aa, bb in d.items():
    print("key:", aa, "value:", bb)
# Out:
# key: 1 value: a
# key: 4 value: b

# %%
print(the_beatles_instruments)

# %%
# NESTED LOOP
# I heard you like loops so I put a loop in a loop...
for member, instruments in the_beatles_instruments.items():
    for instrument in instruments:
        print(member, "plays", instrument)
# Out:
# John plays vocals
# John plays rhythm and lead guitar
# John plays keyboards
# John plays harmonica
# John plays bass guitar
# Paul plays vocals
# Paul plays bass guitar
# Paul plays rhythm and lead guitar
# Paul plays keyboards
# Paul plays drums
# George plays lead and rhythm guitar
# George plays vocals
# George plays sitar
# George plays keyboards
# George plays bass guitar
# Ringo plays drums
# Ringo plays percussion
# Ringo plays vocals
# Pete plays drums

# %% [markdown]
# ## **While Loop**
# runs a part of the code multiple times: until a condition is met

# %%
current_value = 0
while current_value <= 5:
    print("the current value is: ", current_value)
    current_value += 1
# Out:
# the current value is:  0
# the current value is:  1
# the current value is:  2
# the current value is:  3
# the current value is:  4
# the current value is:  5

# %% [markdown]
# ## **Function**
# ways to group and reuse code that can be logically isolated

# %%
# defining a function
def simple_greeting():
    print("Hi")

# %%
# calling a function (using it)
a = simple_greeting()
# Out:
# Hi

# %%
def greeting(name):
    print("Hi,", name)


greeting("Bob")  # passing argument as positional
greeting(name="Bob")  # passing argument as keyword
# Out:
# Hi, Bob
# Hi, Bob

# %%
def greeting_with_default(name="you"):
    print("Hi,", name)


greeting_with_default()
greeting_with_default("Bob")
greeting_with_default(name="Bob")
# Out:
# Hi, you
# Hi, Bob
# Hi, Bob

# %%
# returning values instead of printing it
def duplicate(x):
    print("hello")
    return 2 * x, x


douplex, original = duplicate(3)
original
# Out:
# hello
# 3

# %%
# what happens if I do.. ?
duplicate(duplicate(3))
# Out:
# hello
# hello
# 12

# %% [markdown]
# ## **Classes**
# Classes provide a means of bundling data and functionality together.  Creating a new class creates a new type of object, allowing new instances of that type to be made. Each class instance can have attributes attached to it for maintaining its state. Class instances can also have methods (defined by its class) for modifying its state.

# %%
# defining the class
class Dog:
    def __init__(self, name):
        self.name = name
        self.tricks = []

    def add_trick(self, trick):
        self.tricks.append(trick)


# Don't worry if you don't fully understand the above, focus on the below :)

# creating and using an instance of it
d = Dog("Fido")
d.add_trick("roll over")
d.add_trick("play dead")
d.tricks
# Out:
# ['roll over', 'play dead']

# %% [markdown]
# ## **High-Low**
# using what we have learned so far..
#
# ```input(message)``` is a built-in python function that requests user input showing a message

# %%
import random

CARDS = range(1, 13 + 1)
card = random.choice(CARDS)


def ask_guess(card):
    print("====================")
    print("The current card is", card)
    guess = input('Is the next one going to be higher ("h") or lower ("l")? ("q" to quit)')
    return guess.lower()


def evaluate_result(card, new_card, guess):
    if new_card == card:
        print("They are exactly the same card, you lose :(")
    elif (new_card > card and guess == "h") or (new_card < card and guess == "l"):
        print("Well done! you guessed correcty :)")
    else:
        print("Wrong :(")


guess = ask_guess(card)
while guess != "q":
    new_card = random.choice(CARDS)
    print("The new card is: ", new_card)
    evaluate_result(card, new_card, guess)
    card = new_card
    guess = ask_guess(card)

print("====================")
print("Thanks for playing :)")
# Out:
# ====================
# The current card is 1
# Is the next one going to be higher ("h") or lower ("l")? ("q" to quit)q
# ====================
# Thanks for playing :)

# %% [markdown]
# ## **Exercises**
# mostrly taken from [codewars.com](https://www.codewars.com)

# %%
# Write a program that prints the numbers from 1 to 20.
# But for multiples of three prints “Fizz” instead of the number and for the
# multiples of five print “Buzz”. For numbers which are multiples of both three and five print “FizzBuzz”.

# def evaluate_result(card, new_card, guess):
#     if new_card == card:
#         print('They are exactly the same card, you lose :(')
#     elif (new_card > card and guess == 'h') or (new_card < card and guess == 'l'):
#         print('Well done! you guessed correcty :)')
#     else:
#         print('Wrong :(')


def is_divisible_by(number, divisors):
    is_divisible = True
    for divisor in divisors:
        is_divisible = is_divisible and (number % divisor == 0)
    return is_divisible


for n in range(1, 20 + 1):
    if is_divisible_by(n, [3, 5]):
        print("FizzBuzz")
    elif is_divisible_by(n, [3]):
        print("Fizz")
    elif is_divisible_by(n, [5]):
        print("Buzz")
    else:
        print(n)

# hint: the first prints should be: 1 2 Fizz 4 Buzz Fizz ...
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz

# %%
# Write a function called repeatStr which repeats the given String `s` exactly `n` times.
def repeatStr(n, s):
    overall_text = ""
    for count in range(n):
        overall_text += s
    return overall_text


# Examples:
# repeatStr(6, "I")       >>   "IIIIII"
# repeatStr(5, "Hello")   >>   "HelloHelloHelloHelloHello"
repeatStr(6, "I")

"I" * 6
# Out:
# 'IIIIII'

# %%
# Create a function that removes the first and last characters of a string.
def trim(x):
    trimmed_x = x[1:-1]
    return trimmed_x


# Examples:
# trim("Chocolate")   >>   "hocolat"
# trim("L4W")         >>   "4"

trim("Chocolate")
# Out:
# 'hocolat'

# %%
s = "Chocolate"
s[1:-1]
# Out:
# 'hocolat'

# %%
# you are given a number and have to make it negative. But maybe the number is already negative?
def make_negative(x):
    return -abs(x)


# Examples:
# make_negative(1)    >> -1
# make_negative(-5)   >> -5
# make_negative(0)    >> 0

make_negative(-5)
# Out:
# -5

# %%
# Given an list of integers your solution should find the smallest integer.
def find_min(x):
    current_minimum = x[0]
    for i in x:
        if i < current_minimum:
            current_minimum = i
    return current_minimum


# For example:
# Given [34, 15, 88, 2] your solution will return 2
# Given [34, -345, -1, 100] your solution will return -345


find_min([34, -345, -1, 100])
# Out:
# -345

# %%
# Count the Trues in a list
def count_trues(sequence):
    num_of_true = [True, True, False, True, False, True].count(True)
    return num_of_true


# For example:
# count_trues([True,  True,  False, True,  False,  True]  >>  4

# %%
# Summation
# Write a function that finds the summation of every number from 1 to num. The number will always be a positive integer greater than 0.

# def repeatStr(n, s):
#     overall_text = ""
#     for count in range(n):
#       overall_text += s
#     return overall_text


def summation(x):
    result = 0
    for i in range(1, x + 1):
        result + i
    return result


# For example:
# summation(2) -> 3
# 1 + 2
# summation(8) -> 36
# 1 + 2 + 3 + 4 + 5 + 6 + 7 + 8

# %% [markdown]
# # Dataset Sources
# - https://www.quora.com/What-are-some-interesting-data-sets-available-out-there
# - https://statistics.gov.scot/home
# - https://www.dataquest.io/blog/free-datasets-for-projects/
# - .. or something you work with (and is anonymised enough)
